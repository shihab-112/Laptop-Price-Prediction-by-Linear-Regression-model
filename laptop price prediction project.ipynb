# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
laptop = pd.read_csv("E:\\My Study\\Mechine Learning Theores\\laptop_price.csv")

# %%
laptop.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
laptop.shape
# Out:
# (1303, 12)

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
laptop['Inches'].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 11.6, 17.3, 10.1, 13.5, 12.5, 13. ,
#        18.4, 13.9, 12.3, 17. , 15. , 14.1, 11.3])

# %%
laptop['ScreenResolution'].unique()
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800',
#        'IPS Panel Touchscreen 1920x1200', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', 'Touchscreen 2560x1440',
#        '1600x900', 'IPS Panel 4K Ultra HD 3840x2160',
#        '4K Ultra HD 3840x2160', 'Touchscreen 1366x768',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
# ...

# %%
laptop
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
laptop['Ram'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB'],
#       dtype=object)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
laptop['Ram'] = laptop['Ram'].str.split(' ').str.get(0).str.replace('GB','')

# %%
laptop['Ram']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: object

# %%
laptop['Ram'] = laptop['Ram'].astype('int')

# %%
laptop['Ram']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: int32

# %%
laptop['Weight'] = laptop['Weight'].str.split(' ').str.get(0).str.replace('kg','')

# %%
laptop['Weight'] = laptop['Weight'].astype('float')

# %%
laptop['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1303, dtype: float64

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
laptop.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
laptop.duplicated().sum()
# Out:
# 29

# %%
#we want to see that how much skewed the data is
laptop['Price'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
laptop['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#now we want to see that which comapy's  laptop  price are high and
#which are low/budget laptop
sns.barplot(x=laptop['Company'],y=laptop['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#types of laptop exist in the dataset
laptop['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#types of laptops average price
sns.barplot(x=laptop['TypeName'],y=laptop['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#laptop price little bit increaing when increasing the inches
sns.scatterplot(x=laptop['Inches'],y=laptop['Price'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
laptop['Touchscreen'] = laptop['ScreenResolution'].apply(lambda row:1 if 'Touchscreen' in row else 0)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
laptop.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 386   Lenovo  Notebook    13.3  IPS Panel Full HD 1920x1080
# 690     Acer  Notebook    14.0                     1366x768
# 396   Lenovo  Notebook    15.6  IPS Panel Full HD 1920x1080
# 585      MSI    Gaming    17.3            Full HD 1920x1080
# 1211    Asus  Notebook    15.6            Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 386             Intel Core i3 7100U 2.4GHz    4             128GB SSD
# 690   Intel Celeron Dual Core 3855U 1.6GHz    4    32GB Flash Storage
# 396             Intel Core i7 8550U 1.8GHz    8             256GB SSD
# 585            Intel Core i7 6820HK 2.7GHz   16  128GB SSD +  1TB HDD
# 1211           Intel Core i7 7700HQ 2.8GHz   16  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen
# 386     Intel HD Graphics 620  Windows 10    1.50   29250.7200            0
# ...

# %%
laptop['Touchscreen'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=laptop['Touchscreen'], y=laptop['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
laptop['IPS Panel'] = laptop['ScreenResolution'].apply(lambda row:1 if 'IPS Panel' in row else 0)

# %%
laptop['IPS Panel'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
laptop['IPS Panel'].value_counts()
# Out:
# 0    938
# 1    365
# Name: IPS Panel, dtype: int64

# %%
sns.barplot(x=laptop['IPS Panel'], y=laptop['Price'])
# Out:
# <AxesSubplot:xlabel='IPS Panel', ylabel='Price'>

# %%
new = laptop['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
laptop['x_res'] = new[0] 
laptop['y_res'] = new[1]

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
laptop['x_res']=laptop['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0] if isinstance(x, list) else x)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
laptop['x_res'] = laptop['x_res'].astype(str).astype(int)
laptop['y_res'] = laptop['y_res'].astype(str).astype(int)

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS Panel         1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# ...

# %%
laptop.corr()['Price']# In respect to price the correlation of other variables
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS Panel      0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
laptop['ppi']=(((laptop['x_res']**2) + (laptop['y_res']**2))**.5/laptop['Inches'])

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS Panel         1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
#  15  ppi               1303 non-null   float64
# ...

# %%
laptop.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS Panel      0.252208
# x_res          0.556529
# y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
laptop.drop('ScreenResolution', axis=1, inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Panel  x_res  y_res         ppi
# 0   71378.6832            0          1   2560   1600  226.983005
# ...

# %%
laptop.drop('x_res', axis=1, inplace=True)
laptop.drop('y_res', axis=1, inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Panel         ppi
# 0   71378.6832            0          1  226.983005
# 1   47895.5232            0          0  127.677940
# ...

# %%
laptop['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz              190
# Intel Core i7 7700HQ 2.8GHz             146
# Intel Core i7 7500U 2.7GHz              134
# Intel Core i7 8550U 1.8GHz               73
# Intel Core i5 8250U 1.6GHz               72
#                                        ...
# AMD FX 9830P 3GHz                         1
# Intel Core i7 2.8GHz                      1
# Intel Core i5 7500U 2.7GHz                1
# Intel Core i7 2.9GHz                      1
# Intel Celeron Quad Core N3710 1.6GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
laptop['Cpu Name']=laptop['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Panel         ppi       Cpu Name
# 0   71378.6832            0          1  226.983005  Intel Core i5
# ...

# %%
def fetch_function(text):
    if text == 'Intel Core i7' or text =='Intel Core i5' or text =='Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Funciton'
        else:
            return 'AMD Processor'

# %%
laptop['CPU brand'] = laptop['Cpu Name'].apply(fetch_function)

# %%
laptop['CPU brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='CPU brand',y ='Price', data=laptop)
plt.xticks(rotation='vertical')

plt.show()

# %%
laptop.drop('Cpu Name', axis=1, inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Panel         ppi      CPU brand
# 0   71378.6832            0          1  226.983005  Intel Core i5
# ...

# %%
laptop['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='Ram',y ='Price', data=laptop)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price'>

# %%
laptop['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# ...

# %%
laptop['Memory'] = laptop['Memory'].astype(str).replace('\.0', '', regex=True)
laptop["Memory"] = laptop["Memory"].str.replace('GB', '')
laptop["Memory"] = laptop["Memory"].str.replace('TB', '000')
new = laptop["Memory"].str.split("+", n = 1, expand = True)

laptop["first"]= new[0]
laptop["first"]=laptop["first"].str.strip()

laptop["second"]= new[1]

laptop["Layer1HDD"] = laptop["first"].apply(lambda x: 1 if "HDD" in x else 0)
laptop["Layer1SSD"] = laptop["first"].apply(lambda x: 1 if "SSD" in x else 0)
laptop["Layer1Hybrid"] = laptop["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
laptop["Layer1Flash_Storage"] = laptop["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

laptop['first'] = laptop['first'].str.replace(r'\D', '')

laptop["second"].fillna("0", inplace = True)

laptop["Layer2HDD"] = laptop["second"].apply(lambda x: 1 if "HDD" in x else 0)
laptop["Layer2SSD"] = laptop["second"].apply(lambda x: 1 if "SSD" in x else 0)
laptop["Layer2Hybrid"] = laptop["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
laptop["Layer2Flash_Storage"] = laptop["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

laptop['second'] = laptop['second'].str.replace(r'\D', '')

laptop["first"] = laptop["first"].astype(int)
laptop["second"] = laptop["second"].astype(int)

laptop["HDD"]=(laptop["first"]*laptop["Layer1HDD"]+laptop["second"]*laptop["Layer2HDD"])
laptop["SSD"]=(laptop["first"]*laptop["Layer1SSD"]+laptop["second"]*laptop["Layer2SSD"])
laptop["Hybrid"]=(laptop["first"]*laptop["Layer1Hybrid"]+laptop["second"]*laptop["Layer2Hybrid"])
laptop["Flash_Storage"]=(laptop["first"]*laptop["Layer1Flash_Storage"]+laptop["second"]*laptop["Layer2Flash_Storage"])

laptop.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-65-a6e63d179b09>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   laptop['first'] = laptop['first'].str.replace(r'\D', '')
# <ipython-input-65-a6e63d179b09>:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   laptop['second'] = laptop['second'].str.replace(r'\D', '')

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#               Memory                           Gpu  OpSys  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256 SSD         Intel HD Graphics 620  No OS    1.86
# 3            512 SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256 SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Panel         ppi      CPU brand  HDD  SSD  \
# 0   71378.6832            0          1  226.983005  Intel Core i5    0  128
# ...

# %%
laptop.drop('Memory', axis=1, inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS Panel         ppi      CPU brand  HDD  SSD  Hybrid  Flash_Storage
# 0          1  226.983005  Intel Core i5    0  128       0              0
# ...

# %%
laptop.corr()['Price']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS Panel        0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
laptop.drop(['Hybrid','Flash_Storage'], axis=1, inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS Panel         ppi      CPU brand  HDD  SSD
# 0          1  226.983005  Intel Core i5    0  128
# 1          0  127.677940  Intel Core i5    0    0
# ...

# %%
laptop['Gpu brand']=laptop['Gpu'].apply(lambda x:x.split()[0])

# %%
laptop.drop(['Cpu','Inches'],axis=1,inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Panel         ppi      CPU brand  HDD  SSD  \
# 0   71378.6832            0          1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0          0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0          0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0          1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0          1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
laptop['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
laptop.drop(laptop.index[(laptop["Gpu brand"] == "ARM")],axis=0,inplace=True)

# %%
laptop['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x="Gpu brand", y="Price", data=laptop)
# Out:
# <AxesSubplot:xlabel='Gpu brand', ylabel='Price'>

# %%
laptop.drop('Gpu',axis=1,inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS Panel  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0          1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0          0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0          0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0          1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0          1
#
#           ppi      CPU brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
laptop['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Windows 10 S       8
# Mac OS X           8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x="OpSys", y="Price", data=laptop)
# Out:
# <AxesSubplot:xlabel='OpSys', ylabel='Price'>

# %%
def cat_os(www):
    if www=='Windows 10' or www=='Windows 10 S' or www=='Windows 7':
        return 'Windows'
    elif www=='macOS' or www=='Mac OS X':
        return 'Mac'
    else:
        return 'Other OS'

# %%
laptop['OS'] =  laptop['OpSys'].apply(cat_os)

# %%
laptop.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS Panel  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0          1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0          0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0          0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0          1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0          1
#
#           ppi      CPU brand  HDD  SSD Gpu brand        OS
# 0  226.983005  Intel Core i5    0  128     Intel       Mac
# 1  127.677940  Intel Core i5    0    0     Intel       Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Other OS
# 3  220.534624  Intel Core i7    0  512       AMD       Mac
# 4  226.983005  Intel Core i5    0  256     Intel       Mac

# %%
laptop.drop('OpSys',axis=1,inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS Panel  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0          1
# 1   Apple  Ultrabook    8    1.34   47895.5232            0          0
# 2      HP   Notebook    8    1.86   30636.0000            0          0
# 3   Apple  Ultrabook   16    1.83  135195.3360            0          1
# 4   Apple  Ultrabook    8    1.37   96095.8080            0          1
#
#           ppi      CPU brand  HDD  SSD Gpu brand        OS
# 0  226.983005  Intel Core i5    0  128     Intel       Mac
# 1  127.677940  Intel Core i5    0    0     Intel       Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Other OS
# 3  220.534624  Intel Core i7    0  512       AMD       Mac
# 4  226.983005  Intel Core i5    0  256     Intel       Mac

# %%
sns.barplot(x="OS",y="Price",data=laptop)
# Out:
# <AxesSubplot:xlabel='OS', ylabel='Price'>

# %%
sns.displot(laptop['Weight'],kind='kde')

# %%
sns.scatterplot(data=laptop,x='Weight',y='Price')
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
laptop.corr()
# Out:
#                   Ram    Weight     Price  Touchscreen  IPS Panel       ppi  \
# Ram          1.000000  0.383362  0.742905     0.118875   0.207949  0.305688
# Weight       0.383362  1.000000  0.209867    -0.293004   0.018643 -0.321883
# Price        0.742905  0.209867  1.000000     0.192917   0.253320  0.475368
# Touchscreen  0.118875 -0.293004  0.192917     1.000000   0.148026  0.458571
# IPS Panel    0.207949  0.018643  0.253320     0.148026   1.000000  0.299142
# ppi          0.305688 -0.321883  0.475368     0.458571   0.299142  1.000000
# HDD          0.095808  0.514147 -0.096891    -0.208766  -0.093588 -0.294698
# SSD          0.603379 -0.063818  0.670660     0.257577   0.225311  0.509437
#
#                   HDD       SSD
# Ram          0.095808  0.603379
# Weight       0.514147 -0.063818
# Price       -0.096891  0.670660
# Touchscreen -0.208766  0.257577
# IPS Panel   -0.093588  0.225311
# ppi         -0.294698  0.509437
# HDD          1.000000 -0.400750
# ...

# %%
correlation = laptop.corr()
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
def logTrans(feature):   # function to apply transformer and check the distribution with histogram and kdeplot
    
    logTr = ColumnTransformer(transformers=[("lg", FunctionTransformer(np.log1p), [feature])])

    plt.figure(figsize=(15,6))
    plt.subplot(1,2,1)
    plt.title("Distribution before Transformation", fontsize=15)
    sns.histplot(laptop[feature], kde=True, color="red")
    plt.subplot(1,2,2)
    
    laptop_log = pd.DataFrame(logTr.fit_transform(laptop))
    plt.title("Distribution after Transformation", fontsize=15)
    sns.histplot(laptop_log,bins=20, kde=True , legend=False)
    plt.xlabel(feature)
    plt.show()
    
logTrans(feature="Price")

# %%
X = laptop.drop(columns=['Price'])
y = np.log(laptop['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS Panel  \
# 0      Apple           Ultrabook    8    1.37            0          1
# 1      Apple           Ultrabook    8    1.34            0          0
# 2         HP            Notebook    8    1.86            0          0
# 3      Apple           Ultrabook   16    1.83            0          1
# 4      Apple           Ultrabook    8    1.37            0          1
# ...      ...                 ...  ...     ...          ...        ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1          1
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1          1
# 1300  Lenovo            Notebook    2    1.50            0          0
# 1301      HP            Notebook    6    2.19            0          0
# 1302    Asus            Notebook    4    2.20            0          0
#
#              ppi             CPU brand   HDD  SSD Gpu brand        OS
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  IPS Panel  \
# 183   Toshiba            Notebook    8    2.00            0          0
# 1141      MSI              Gaming    8    2.40            0          0
# 1049     Asus             Netbook    4    1.20            0          0
# 1020     Dell  2 in 1 Convertible    4    2.08            1          1
# 878      Dell            Notebook    4    2.18            0          0
# ...       ...                 ...  ...     ...          ...        ...
# 466      Acer            Notebook    4    2.20            0          0
# 299      Asus           Ultrabook   16    1.63            0          0
# 493      Acer            Notebook    8    2.20            0          0
# 527    Lenovo            Notebook    8    2.20            0          0
# 1193    Apple           Ultrabook    8    0.92            0          1
#
#              ppi             CPU brand   HDD  SSD Gpu brand        OS
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277450155151
# MAE 0.2101782795301903
